# %%
_ = """
# !pip3 install lxml beautifulsoup4 argparse PyMySql pandas numpy urllib3
"""

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import threading


from pprint import PrettyPrinter
pp = PrettyPrinter(indent=4)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import threading


from pprint import PrettyPrinter
pp = PrettyPrinter(indent=4)

# %%
francise_resp = requests.get(
    "https://franchise.ftc.go.kr/mnu/00013/program/userRqst/view.do?firMstSn=133332",
    params = {'firMstSn': ['442232']}
)
print(francise_resp.url)
# Out:
# https://franchise.ftc.go.kr/mnu/00013/program/userRqst/view.do?firMstSn=133332&firMstSn=442232

# %%
francise_resp.content
# Out:
# b'\r\n\r\n\r\n\r\n\r\n\r\n    \r\n    \r\n    \r\n    \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="robots" content="noindex">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n    <meta name="viewport" content="initial-scale=1.0, width=device-width, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\r\n\r\n    <title>\r\n        \r\n            \r\n            \r\n            \r\n                 \xea\xb0\x80\xeb\xa7\xb9\xec\x82\xac\xec\x97\x85\xea\xb1\xb0\xeb\x9e\x98 > \xec\xa0\x95\xeb\xb3\xb4\xea\xb3\xb5\xea\xb0\x9c\xec\x84\x9c > \xec\xa0\x95\xeb\xb3\xb4\xea\xb3\xb5\xea\xb0\x9c\xec\x84\x9c \xec\x97\xb4\xeb\x9e\x8c\r\n            \r\n        \r\n    </title>\r\n\r\n    <!-- css -->\r\n    <link rel="stylesheet" href="/template/common/css/jquery-ui.css">\r\n    <link rel="stylesheet" href="/template/site/00001/common.css">\r\n    <link rel="stylesheet" href="/template/site/00001/main.css">\r\n    <link rel="stylesheet" href="/template/site/00001/css/sub.css">\r\n\r\n    <script src="/template/common/js/jquery-1.12.4.min.js"></script>\r\n    <script src="/template/common/js/jquery-ui.js"></script>\r\n    <script src="/template/common/js/common.js"></script>\r\n    <script src="/template/site/00001/main.js"></script>\r\n    <script src="/template/common/js/diff_match_patch.js"></script>\r\n    <script src="/template/common/js/slick.min.js"></script>\r\n\r\n    <link rel="shortcut icon" type="image/x-icon" href="/template/common/images/favicon.ico">\r\n\r\n    <!--[if lte IE 9]>\r\n    <script src="/template/common/js/html5.js"></script>\r\n    <![endif]-->\r\n\r\n    <script>\r\n        $(document).ready(function(){\r\n            $("#selUpjong1").val("").prop("selected", true);\r\n\r\n\r\n            var slider = $(\'.popupZoneSlider\').slick({\r\n                autoplay: true,\r\n                autoplaySpeed: 5000,\r\n                speed: 500,\r\n                dots : false,\r\n                prevArrow : $(\'#popupZonePrev\'),\r\n                nextArrow : $(\'#popupZoneNext\')\r\n\r\n            });\r\n\r\n            slider.on(\'afterChange\', function(event, slick, currentSlide){\r\n                console.log($(".slick-slide"));\r\n                $(".slick-slide").attr(\'tabindex\',\'-1\');\r\n            });\r\n\r\n            $(\'#popupZonePrev\').on(\'click\', function() {\r\n                $(\'.popupZoneSlider\').slick(\'prev\');\r\n            });\r\n            $(\'#popupZoneNext\').on(\'click\', function() {\r\n                $(\'.popupZoneSlider\').slick(\'next\');\r\n            });\r\n            $(\'#popupZoneToggle\').on(\'click\', function() {\r\n                if($(\'#popupZoneToggle\').val() ==\'\xe2\x96\xa0\'){\r\n                    $(\'#popupZoneToggle\').val("\xe2\x96\xb6");\r\n                    $(\'#popupZoneToggle\').attr("title","\xec\x9e\xac\xec\x83\x9d");\r\n                    $(\'.popupZoneSlider\').slick(\'slickPause\')\r\n                } else{\r\n                    $(\'#popupZoneToggle\').val("\xe2\x96\xa0");\r\n                    $(\'#popupZoneToggle\').attr("title","\xeb\xa9\x88\xec\xb6\xa4");\r\n                    $(\'.popupZoneSlider\').slick(\'slickPlay\')\r\n                }\r\n            });\r\n\r\n            $(".slick-slide").attr(\'tabindex\',\'-1\');\r\n        });\r\n\r\n        function searchFrm1(){\r\n            if($("strYear1").val() == ""){\r\n                alert("\xeb\x85\x84\xeb\x8f\x84\xeb\xa5\xbc \xec\x84\xa0\xed\x83\x9d\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94.");\r\n                return;\r\n            }\r\n\r\n            document.frmSearch1.action ="/mnu/00014/program/firHope/view.do"\r\n            document.frmSearch1.submit();\r\n        }\r\n\r\n        function searchFrm2(){\r\n            if($("selYear2").val() == ""){\r\n                alert("\xeb\x85\x84\xeb\x8f\x84\xeb\xa5\xbc \xec\x84\xa0\xed\x83\x9d\xed\x95\xb4 ...
